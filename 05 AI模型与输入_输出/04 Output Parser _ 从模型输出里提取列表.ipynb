# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import CommaSeparatedListOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "{parser_instructions}"),
    ("human", "列出5个{subject}色系的十六进制颜色码。")
])

# %%
output_parser = CommaSeparatedListOutputParser()
parser_instructions = output_parser.get_format_instructions()
print(parser_instructions)
# Out:
# Your response should be a list of comma separated values, eg: `foo, bar, baz` or `foo,bar,baz`

# %%
final_prompt = prompt.invoke({"subject": "莫兰迪", "parser_instructions": parser_instructions})

# %%
model = ChatOpenAI(model="gpt-3.5-turbo")
response = model.invoke(final_prompt)
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model = ChatOpenAI(model="gpt-3.5-turbo")
#       2 response = model.invoke(final_prompt)
#       3 print(response.content)
#
# File D:\software\python\Python_code\.venv\Lib\site-packages\langchain_core\load\serializable.py:118, in Serializable.__init__(self, *args, **kwargs)
#     116 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     117     """"""  # noqa: D419  # Intentional blank docstring
# --> 118     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File D:\software\python\Python_code\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1071, in BaseChatOpenAI.validate_environment(self)
#    1061         self.http_async_client = httpx.AsyncClient(
#    1062             proxy=self.openai_proxy, verify=global_ssl_context
#    1063         )
#    1064     async_specific = {
#    1065         "http_client": self.http_async_client
#    1066         or _get_default_async_httpx_client(
#    (...)   1069         "api_key": async_api_key_value,
#    1070     }
# -> 1071     self.root_async_client = openai.AsyncOpenAI(
#    1072         **client_params,
#    1073         **async_specific,  # type: ignore[arg-type]
#    1074     )
#    1075     self.async_client = self.root_async_client.chat.completions
#    1076 return self
#
# File D:\software\python\Python_code\.venv\Lib\site-packages\openai\_client.py:496, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     494     api_key = os.environ.get("OPENAI_API_KEY")
#     495 if api_key is None:
# --> 496     raise OpenAIError(
#     497         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     498     )
#     499 if callable(api_key):
#     500     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
output_parser.invoke(response)
# Out:
# ['#FF6B6B', '#FF8E53', '#FFC93C', '#FFD166', '#99E2D0']
